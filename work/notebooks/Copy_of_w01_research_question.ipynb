# %% [markdown]
# <a href="https://colab.research.google.com/github/suha-2004/flyrank-ml-internship/blob/main/Copy_of_w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/suha-2004/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# My lane:
# Refresh / Content Opportunity Scoring
#
# Why:
# I selected this lane because identifying pages that may need review can help content teams prioritize their limited time. The goal is not to guarantee that a page will improve after changes, but to rank pages that show signals of possible opportunity or risk.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# Research Question:
# Which pages should be reviewed first based on observable content and search performance signals?
#
# Decision:
# Decide which pages deserve attention from a content team.
#
# Action:
# A reviewer can inspect high-priority pages and decide whether to refresh, improve, monitor, or leave them unchanged.
#
# Cost of a wrong recommendation:
# The team may waste time updating pages that do not need changes, while important opportunities may be missed.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# Quick look at the data:
#
# I loaded the starter dataset and observed the following:
#
# - The dataset contains 30,000 rows of content data.
# - The average number of impressions over 90 days is approximately 5200.37.
# - The average CTR in the dataset is approximately 0.51.
#
# These numbers suggest that the dataset contains enough observable search performance information to explore content opportunity scoring.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# I can claim:
# The dataset can help identify patterns between observable content/search signals and pages that may deserve review.
#
# I cannot claim:
# This proves why a page performs poorly or guarantees that a recommended update will improve performance.

# %%
import os

print(os.getcwd())
print(os.listdir())
# Out:
# /content
# ['.config', 'sample_data']

# %%
import os

for root, dirs, files in os.walk('/content'):
    for file in files:
        if file == "content_refresh_anonymized.csv":
            print(os.path.join(root, file))
# Out:
# /content/flyrank-ml-internship/data/raw/content_refresh_anonymized.csv

# %%
# !git clone https://github.com/suha-2004/flyrank-ml-internship.git
# Out:
# Cloning into 'flyrank-ml-internship'...
# remote: Enumerating objects: 117, done.
# remote: Counting objects: 100% (117/117), done.
# remote: Compressing objects: 100% (73/73), done.
# remote: Total 117 (delta 33), reused 96 (delta 28), pack-reused 0 (from 0)
# Receiving objects: 100% (117/117), 1.84 MiB | 14.63 MiB/s, done.
# Resolving deltas: 100% (33/33), done.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("/content/flyrank-ml-internship/data/raw/content_refresh_anonymized.csv")

print("Number of rows:", len(df))
print("Average impressions:", df["impressions_90d"].mean())
print("Average CTR:", df["ctr"].mean())
# Out:
# Number of rows: 30000
# Average impressions: 5200.3663
# Average CTR: 0.5107333333333334

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
